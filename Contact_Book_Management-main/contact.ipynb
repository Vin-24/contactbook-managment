# %% [markdown]
# # Contact Book Management

# %%
# open contact
# search contact
# add contact 
# update name and number 
# delete contact 
# 0 for back to menu       

 print('''Want 2nd number Press Y/N''')
        want_num = input().title()
        if want_num == 'Y':
            c = int(input("Number1: "))
            if c in contact_data.values: 
                print('\nNumber already exist \nPress 1 to Update Name \nPress 2 For Other Number','\n',contact_data[contact_data.Number1==c])
                input12 = int(input('\nOption: '))
                if input12 == 1:
                    contact_data.loc[contact_data[contact_data.Number==b].index.values,'Name']=input('Enter new Name: ').title()
                    return
                else: c = int(input("Number: "))
            else:     c=c
        else:         c = np.nan

# %%
import numpy as np
import pandas as pd
try:
    contact_data = pd.read_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
    contact_data.drop('Unnamed: 0',axis=1,inplace=True)
except:
    di = [{'Name': "Akshat",'Number':'1','Number1':'2','Number2':'3','Email':'Abc@123','NickName':'Akku'}]
    contact_data = pd.DataFrame(di)

# %%
# di = [{'Name': "Akshat",'Number':'1','Number1':'2','Number2':'3','Email':'Abc@123','NickName':'Akku'}]
# contact_data = pd.DataFrame(di)
# contact_data

# %%
def add_details():
    
    while 1:
        
        print("\nAdd Details")
        a = input("Name:").title()
        b = input("Number: ")   # number 1

        print('''Want more number press Y/N''')
        want_num = input().title()
        if want_num == 'Y':
            c = input("Number1: ")
        else:
            c = np.nan

        print('''Want more number press Y/N''')
        want_num1 = input().title()
        if want_num1 == 'Y':
            d = input("Number2: ")
        else:
            d = np.nan    # this will give null value (Nan)

        e = input("Email: ").title()
        f = input("NickName: ").title()
        dic = dict(zip(contact_data.columns,[a,b,c,d,e,f]))
        contact_data.loc[len(contact_data)] = [a,b,c,d,e,f]

        print('\nSuccessful','\n',contact_data)

        #     here its for the end or go back to menu
        print('''
        Press 1 to Retry 
        Press 2 to go back to Menu
        Press 0 to Exit ''')

        input12 = int(input("\nOption: "))
        if input12 == 1:
            continue           # to return to same function 
        if input12 == 2:
            return             # to return to menu function 
        else:
            print("Thank you!!!")
            break              # to break the function
# Out:
# Add Details
# Name:hjg
# Number: gcvg
# Want more number press Y/N
# vfhjgh
# Want more number press Y/N
# n
# Email: hg
# NickName: hh
#
# Successful
#       Name Number  Number1  Number2            Email NickName
# 0  Akshat      1      2.0      3.0          Abc@123     Akku
# 1     Dev    455      NaN      NaN  Dev12@Gmail.Com     Devu
# 2     Hjg   gcvg      NaN      NaN               Hg       Hh
#
#         Press 1 to Retry
#         Press 2 to go back to Menu
#         Press 0 to Exit
#
# Option: 2

# %%
def search_data():
    
    while 1:
        
        print('''Search on the basis of
        Name     Press 1
        Number   Press 2
        Email    Press 3
        NickName Press 4''')
        num = int(input("Option: "))
        if num == 1:

            name1 = input("\nName: ").title()
            print("\n")
            print(contact_data[contact_data.Name == name1 ])

            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break

        elif num == 2:
            name1 = input("\nNumber: ").title()
            print("\n")
            print(contact_data[contact_data.Number == name1 ])

            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break



        elif num == 3:
            name1 = input("\nEmail: ").title()
            print("\n")
            print(contact_data[contact_data.Email == name1 ])

            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break


        elif num == 4:
            name1 = input("\nNickName: ").title()
            print("\n")
            print(contact_data[contact_data.NickName == name1 ]) 

            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break


        else:
            print('''Invalid input......
                     Please try Again.... ''')

            print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')

            input12 = int(input("\nOption: "))
            if input12 == 1:
                continue           # to return to same function 
            if input12 == 2:
                return             # to return to menu function 
            else:
                print("Thank you!!!")
                break              # to break the function

search_data()
# Out:
# Search on the basis of
#         Name     Press 1
#         Number   Press 2
#         Email    Press 3
#         NickName Press 4
# Option: 1
#
# Name: ak
#
#
#   Name Number  Number1  Number2 Email NickName
# 2   Ak     65      NaN      NaN   Bhg     Akki
#
#             Press 1 to go back to Menu
#             Press 0 to Exit
#
# Option: 1

# %%
def delete_data():
    
    while 1:
        
        print('''Delete on the basis of
                Name Press 1
                Number Press 2
                Email Press 3
                NickName Press 4''')
        num = int(input("Option: "))

        if num == 1:

            name1 = input("\nName: ").title()
            print("\n")
            n = (contact_data[contact_data.Name == name1 ])
            y= list(n.index)
            contact_data.drop(index = y , inplace = True)
            print('successfully Done')
            print(contact_data)
            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break

        elif num == 2:

            name1 = input("\nNumber: ").title()
            print("\n")
            n = (contact_data[contact_data.Number == name1 ])
            y= list(n.index)
            contact_data.drop(index = y , inplace = True)
            print('successfully Done')
            print(contact_data)
            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break

        elif num == 3:

            name1 = input("\nEmail: ").title()
            print("\n")
            n = contact_data[contact_data.Email == name1 ]
            y= list(n.index)
            contact_data.drop(index = y , inplace = True)
            print('successfully Done')
            print(contact_data)
            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break

        elif num == 4:

            name1 = input("\nNickName: ").title()
            print("\n")
            n = (contact_data[contact_data.NickName == name1 ]) 
            y= list(n.index)
            contact_data.drop(index = y , inplace = True)
            print('successfully Done')
            print(contact_data)
            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break

        else:
            print('''Invalid input......
                     Please try Again.... ''')

            print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')

            input12 = int(input("\nOption: "))
            if input12 == 1:
                continue           # to return to same function 
            if input12 == 2:
                return             # to return to menu function 
            else:
                print("Thank you!!!")
                break              # to break the function

# %%
def update_numbers():
    
    while True:
        
        print('''Press 1 to update number 1
        Press 2 to update number 2
        Press 3 to update number 3''')
        num2 = int(input('Option: '))
        if num2 == 1:
            name1 = input("\nEnter Person Name: ").title()
            print("\n")
            n = (contact_data[contact_data.Name == name1 ])
            y= list(n.index)
            new = input('Enter new number: ')
            contact_data['Number'].loc[y] = new

            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break

        elif num2 == 2:
            name1 = input("\nEnter Person Name: ").title()
            print("\n")
            n = (contact_data[contact_data.Name == name1 ])
            y= list(n.index)
            new = input('Enter new number: ')
            contact_data['Number1'].loc[y] = new

            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break

        elif num2 == 3:
            name1 = input("\nEnter Person Name: ").title()
            print("\n")
            n = (contact_data[contact_data.Name == name1 ])
            y= list(n.index)
            new = input('Enter new number: ')
            contact_data['Number2'].loc[y] = new

            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break

        else:
            print('''Invalid input......
                 Please try Again.... ''')

            print('''
            Press 1 to Retry 
            Press 2 to go back to Menu
            Press 0 to Exit ''')
           
            input12 = int(input("\nOption: "))
            if input12 == 1:
                continue           # to return to same function 
            if input12 == 2:
                return             # to return to menu function 
            else:
                print("Thank you!!!")
                break              # to break the function

# %%
def update_data():
    
    while True:
        
        print('''To Update Data of 
        Name     Press 1
        Number   Press 2
        Email    Press 3
        NickName Press 4''')
        num1 = int(input("Option: "))

        if num1 == 1:

            name1 = input("\nName: ").title()
            print("\n")
            n = (contact_data[contact_data.Name == name1 ])
            y= list(n.index)
            new = input('Enter new name: ').title()
            contact_data['Name'].loc[y[0]] = new

            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break


        elif num1 == 2:

            update_numbers()

        elif num1 == 3:

            name1 = input("\nEmail: ").title()
            print("\n")
            n = contact_data[contact_data.Email == name1 ]
            y= list(n.index)
            new = input('Enter new name: ').title()
            contact_data['Email'].loc[y[0]] = new

            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break

        elif num1 == 4:

            name1 = input("\nNickName: ").title()
            print("\n")
            n = (contact_data[contact_data.NickName == name1 ]) 
            y= list(n.index)
            new = input('Enter new name: ').title()
            contact_data['NickName'].loc[y[0]] = new

            print('''
            Press 1 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            
            if input12 == 1:
                return
            else:
                print("Thank you!!! \nInvalid Input")
                
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu
                Press 0 to Exit ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    return
                else:
                    print("Thank you!!!")
                    break

        else:
            print('''Invalid input......
                     Please try Again.... ''')
            print('''
            Press 1 to Retry 
            Press 2 to go back to Menu
            Press 0 to Exit ''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                continue
            if input12 == 2:
                return
            else:
                print("Thank you!!!")
                break

# %%
def Contact_Book():
    flag = 4
    print('''
        .....Welcome to Contact Book Mangement.....
        ...........To Open Press Y/N..............
        ''')
    open1 = input('Y/N: ').title()
    if open1 == 'Y':
        while flag:
                print('''
                To Open Contact Book                 Press 1
                To Search Contact                    Press 2
                To Add New Contact                   Press 3
                To Update Name/Number/Email/NickName Press 4
                To Delete Contact                    Press 5
                To Exit                              Press 0
                ''')
                Option1 = int(input('Option: '))
                if Option1 == 1:
                    print(contact_data)

                elif Option1 == 2:
                    search_data()

                elif Option1 == 3:
                    add_details()

                elif Option1 == 4:
                    update_data()

                elif Option1 == 5:
                    delete_data()

                elif Option1 == 0 :
                    break

                else:
                    print(f'Please Try Again You Got {flag - 1} chance')
                    flag-=1

    else:
        print('Thank You!!!!!!')

# %%
Contact_Book()
contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
# Out:
#         .....Welcome to Contact Book Mangement.....
#         ...........To Open Press Y/N..............
#
# Y/N: y
#
#                 To Open Contact Book                 Press 1
#                 To Search Contact                    Press 2
#                 To Add New Contact                   Press 3
#                 To Update Name/Number/Email/NickName Press 4
#                 To Delete Contact                    Press 5
#                 To Exit                              Press 0
#
# Option: 5
# Delete on the basis of
#                 Name Press 1
#                 Number Press 2
#                 Email Press 3
#                 NickName Press 4
# Option: 1
#
# Name: ak
#
#
# successfully Done
#      Name Number  Number1  Number2              Email NickName
# 0  Akshat      1      2.0      3.0            Abc@123     Akku
# 1     Dev    455      NaN      NaN    Dev12@Gmail.Com     Devu
# 2     Hjg   gcvg      NaN      NaN                 Hg       Hh
# 3   Vinay  45454      NaN      NaN  Vinay12@Gmail.Com     Vinu
# 4     Mom  98548      NaN      NaN              Jhuh'       Jb
#
#             Press 1 to go back to Menu
#             Press 0 to Exit
#
# Option: 0
# Thank you!!!
# Invalid Input
#
#                 Press 1 to Retry
#                 Press 2 to go back to Menu
#                 Press 0 to Exit
#
# Option: 1
# Delete on the basis of
#                 Name Press 1
#                 Number Press 2
#                 Email Press 3
#                 NickName Press 4
# Option: 1
#
# Name: akshat
#
#
# successfully Done
#     Name Number  Number1  Number2              Email NickName
# 1    Dev    455      NaN      NaN    Dev12@Gmail.Com     Devu
# 2    Hjg   gcvg      NaN      NaN                 Hg       Hh
# 3  Vinay  45454      NaN      NaN  Vinay12@Gmail.Com     Vinu
# 4    Mom  98548      NaN      NaN              Jhuh'       Jb
#
#             Press 1 to go back to Menu
#             Press 0 to Exit

# %%
df = pd.read_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')

# %%
df
# Out:
#    Unnamed: 0    Name  Number  Number1  Number2            Email NickName
# 0           0  Akshat       1      2.0      3.0          Abc@123     Akku
# 1           1     Dev     455      NaN      NaN  Dev12@Gmail.Com     Devu
