# %% [markdown]
# # Contact Book Management

# %%
# open contact
# search contact
# add contact 
# update name and number 
# delete contact 
# 0 for back to menu

# %%
import numpy as np
import pandas as pd
import winsound
try:
    contact_data = pd.read_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
    contact_data.drop('Unnamed: 0',axis=1,inplace=True)
except:
    di = [{'Name': "Akshat",'Number':1,'2nd Number': 2,'3rd Number':3,'Email':'abc@123','NickName':'Akku'}]
    contact_data = pd.DataFrame(di)

# %%
def update_contact(a):
    
    new = input('Enter new Name: ').title()
    contact_data.loc[contact_data[contact_data.Name== a].index.values,'Name']=new

    contact_data.loc[contact_data[contact_data.Name== new].index.values,'Number']=int(input('Enter new Number: '))
    
    l=['2nd Number','3rd Number','Email','NickName']
    
    for i in l:
        print(f'Do You want to Update Your {i} Y/N')
        want_num = input().title()
        if want_num == 'Y': 
            contact_data.loc[contact_data[contact_data.Name==new].index.values,i]=int(input('Enter new Number: '))
        else:               pass
            
#     print('Do You want to Update Your 2nd Number Y/N')
#     want_num = input().title()
#     if want_num == 'Y': contact_data.loc[contact_data[contact_data.Name==new].index.values,'Number1']=int(input('Enter new Number: '))
#     else:               pass

#     print('Do You want to Update Your 3rd Number Y/N')
#     want_num1 = input().title()
#     if want_num1 == 'Y': contact_data.loc[contact_data[contact_data.Name==new].index.values,'Number2']=int(input('Enter new Number: '))
#     else:                pass
    
#     print('Do You want to Update Your Email Y/N')
#     want_num1 = input().title()
#     if want_num1 == 'Y': contact_data.loc[contact_data[contact_data.Name== new].index.values,'Email']=input('Enter new Email: ')
#     else:                pass
    
#     print('Do You want to Update Your NickName Y/N')
#     want_num1 = input().title()
#     if want_num1 == 'Y': contact_data.loc[contact_data[contact_data.Name== new].index.values,'NickName']=input('Enter new NickName: ').title()
#     else:                pass

    print('\nDone Successful','\n',contact_data)
    winsound.PlaySound('FILENAMEHERE.wav', winsound.SND_FILENAME)

# %% [markdown]
# # Add Details

# %%
def add_details():
    
    while 1:
        # Name
        a = input("Add Details \nName: ").title()
        if a in contact_data.Name.values: 
            print('\nName already exist \nPress 1 to Update Contact \nPress 2 For Other Name','\n',contact_data[contact_data.Name == a ])
            input12 = int(input('\nOption: '))
            if input12 == 1:
                update_contact(a)
                return
            elif input12 ==2:
                a = int(input("Number: "))
                if a in contact_data.Name.values:
                    print('\nName already exist Use Other Number')
                    a = int(input("New Number: "))
                else: a=a
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
        else: a=a
        
        # Number        
        b = int(input("\nNumber: "))   # number 1
        if b in contact_data.values:
            print('\nNumber already exist \nPress 1 to Update Name \nPress 2 For Other Number','\n',contact_data[contact_data.Number==b])
            input12 = int(input('\nOption: '))
            if input12 == 1:
                contact_data.loc[contact_data[contact_data.Number==b].index.values,'Name']=input('Enter new Name: ').title()
                return
            elif input12 ==2:
                b = int(input("Number: "))
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
        else: b=b
        # Number 2
        print('''Want 2nd number press Y/N''')
        want_num = input().title()
        if want_num == 'Y':   c = input("Number1: ")
        elif want_num=='N':   c = np.nan
        else:
            print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')
            input12 = int(input("\nEnter Option Number: "))
            if input12 == 1:    continue
            elif input12 == 2:  return
        # Number3
        print('''Want 3rd number press Y/N''')
        want_num = input().title()
        if want_num == 'Y':   d = input("Number1: ")
        elif want_num=='N':   d = np.nan
        else:
            print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')
            input12 = int(input("\nEnter Option Number: "))
            if input12 == 1:    continue
            elif input12 == 2:  return

        e = input("Email: ")
        f = input("NickName: ").title()
        
        dic = dict(zip(contact_data.columns,[a,b,c,d,e,f]))
        contact_data.loc[len(contact_data)] = [a,b,c,d,e,f]
        print('\nSuccessful','\n',contact_data,'\nPress 1 to Retry \nPress 2 to go back to Menu')
        winsound.PlaySound('FILENAMEHERE.wav', winsound.SND_FILENAME)
        contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')

        input12 = int(input("\nEnter Option Number: "))
        if input12 == 1:    continue          ## to return to same function 
        elif input12 == 2:  return            # to return to menu function 
# add_details()

# %% [markdown]
# # Search data

# %%
def search_data():
    
    while 1:       
        print('''\nSearch on the basis of
        Name     Press 1
        Number   Press 2
        Email    Press 3
        NickName Press 4''')
        num = (input("Enter Option Number: "))
        if num == '1':
            name1 = input("\nName: ").title()
            if name1 in contact_data.Name.values:
                print(contact_data[contact_data.Name == name1 ],'\nPress 1 to Retry \nPress 2 to go back to Menu ')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return 
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return

        elif num == '2':
            name1 = int(input("\nNumber: "))
            if name1 in contact_data.Number.values:
                print(contact_data[contact_data.Number == name1 ],'\nPress 1 to Retry \nPress 2 to go back to Menu ')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return    
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
                
        elif num == '3':
            name1 = input("\nEmail: ")
            if name1 in contact_data.Email.values:
                print(contact_data[contact_data.Email == name1 ],'\nPress 1 to Retry \nPress 2 to go back to Menu ')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')               
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
                
        elif num == '4':
            name1 = input("\nNickName: ").title()
            if name1 in contact_data.NickNme.values:
                print(contact_data[contact_data.NickName == name1 ],'\nPress 1 to Retry \nPress 2 to go back to Menu ') 
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')                
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return

        else:
            print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')  
            input12 = int(input("\nEnter Option Number: "))
            if input12 == 1:    continue          ## to return to same function 
            elif input12 == 2:  return            # to return to menu function 
            
# search_data()

# %% [markdown]
# # Delete Data

# %%
def delete_data():
    
    while 1: 
        print('''Delete on the basis of
                Name     Press 1
                Number   Press 2
                Email    Press 3
                NickName Press 4''')
        
        num = (input("Enter Option Number: "))
        if num == '1':
            name1 = input("\nName: ").title()
            if name1 in contact_data.values:
                n = list((contact_data[contact_data.Name == name1 ]).index)
                contact_data.drop(index = n , inplace = True)
                print('\nsuccessfully Done','\n',contact_data,'\nPress 1 to Retry \nPress 2 to go back to Menu ')
                winsound.PlaySound('FILENAMEHERE.wav', winsound.SND_FILENAME)

                contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return 
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')                
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return

        elif num == '2':
            name1 = input("\nNumber: ").title()
            if name1 in contact_data.values:
                n = list((contact_data[contact_data.Number == name1 ]).index)
                contact_data.drop(index = n , inplace = True)
                print('\nsuccessfully Done','\n',contact_data,'\nPress 1 to Retry \nPress 2 to go back to Menu ')
                winsound.PlaySound('FILENAMEHERE.wav', winsound.SND_FILENAME)
                
                contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return

        elif num == '3':
            name1 = input("\nEmail: ")
            if name1 in contact_data.values:
                n = list((contact_data[contact_data.Email == name1 ]).index)
                contact_data.drop(index = n , inplace = True)
                print('\nsuccessfully Done','\n',contact_data,'\nPress 1 to Retry \nPress 2 to go back to Menu ')
                winsound.PlaySound('FILENAMEHERE.wav', winsound.SND_FILENAME)
                
                contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
                
        elif num == '4':
            name1 = input("\nNickName: ").title()
            if name1 in contact_data.values:
                n = list((contact_data[contact_data.NickName == name1 ]).index)
                contact_data.drop(index = n , inplace = True)
                print('\nsuccessfully Done','\n',contact_data,'\nPress 1 to Retry \nPress 2 to go back to Menu ')
                winsound.PlaySound('FILENAMEHERE.wav', winsound.SND_FILENAME)
                
                contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
        else:
            print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')  
            if input12 == 1:    continue          ## to return to same function 
            elif input12 == 2:  return            # to return to menu function

# %% [markdown]
# # Update Data of Numbers

# %%
def update_numbers():
    
    while True:
        print('''
        Press 1 to update number 1
        Press 2 to update number 2
        Press 3 to update number 3''')
        num2 = (input("Enter Option Number: "))
        if num2 == '1':
            name1 = input("\nEnter Person Name: ").title()
            if name1 in contact_data.Number.values: 
                contact_data.loc[contact_data[contact_data.Name==name1].index.values,'Number']=int(input('\nEnter new number: '))
                print('\nsuccessfully Done','\n',contact_data,'\nPress 1 to Retry \nPress 2 to go back ')
                winsound.PlaySound('FILENAMEHERE.wav', winsound.SND_FILENAME)
                
                contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back ')                
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return

        elif num2 == '2':
            name1 = input("\nEnter Person Name: ").title()
            if name1 in contact_data.Number1.values: 
                contact_data.loc[contact_data[contact_data.Name==name1].index.values,'Number1']=int(input('\nEnter new number: '))
                print('\nsuccessfully Done','\n',contact_data,'\nPress 1 to Retry \nPress 2 to go back')
                winsound.PlaySound('FILENAMEHERE.wav', winsound.SND_FILENAME)
                
                contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return  
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back')              
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return

        elif num2 == '3':
            name1 = input("\nEnter Person Name: ").title()
            if name1 in contact_data.Number2.values: 
                contact_data.loc[contact_data[contact_data.Name==name1].index.values,'Number2']=int(input('\nEnter new number: '))
                print('\nsuccessfully Done','\n',contact_data,'\nPress 1 to Retry \nPress 2 to go back')
                winsound.PlaySound('FILENAMEHERE.wav', winsound.SND_FILENAME)
                
                contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return    
            else:
                print('Invalid Input \nPress 1 to Retry \nPress 2 to go back ') 
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
        else:
            print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')  
            input12 = int(input("\nEnter Option Number: "))
            if input12 == 1:    continue          ## to return to same function 
            elif input12 == 2:  return            # to return to menu function 
# update_numbers()

# %% [markdown]
# # Update data

# %%
def update_data():
    
    while True:    
        print('''To Update Data of 
        Name     Press 1
        Number   Press 2
        Email    Press 3
        NickName Press 4
        Menu     Press 5''')
        num1 = (input("Enter Option Number: "))
        if num1 == '1':
            name1 = input("\nEnter old Name: ").title()
            if name1 in contact_data.Name.values: 
                contact_data.loc[contact_data[contact_data.Name==name1].index.values,'Name']= input('\nEnter new Name: ').title()
                print('\nsuccessfully Done','\n',contact_data,'\nPress 1 to Retry \nPress 2 to go back to Menu ')
                winsound.PlaySound('FILENAMEHERE.wav', winsound.SND_FILENAME)
                
                contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
            else:
                print("Name Doesn't Exist \nPress 1 to Retry \nPress 2 to go back to Menu ") 
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return

        elif num1 == '2':
            update_numbers()

        elif num1 == '3':
            name1 = input("\nEnter old Email: ")
            if name1 in contact_data.Email.values:
                contact_data.loc[contact_data[contact_data.Email==name1].index.values,'Email']= input('Enter new Email: ')
                print('\nsuccessfully Done','\n',contact_data,'\nPress 1 to Retry \nPress 2 to go back to Menu ')
                winsound.PlaySound('FILENAMEHERE.wav', winsound.SND_FILENAME)
                
                contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
            else:
                print("Number Doesn't Exist \nPress 1 to Retry \nPress 2 to go back to Menu ")                
                input12 = int(input("\nEnter Option Number:  "))
                if input12 == 1:    continue
                elif input12 == 2:  return

        elif num1 == '4':
            name1 = input("\nEnter old NickName: ").title()
            if name1 in contact_data.NickName.values:              
                contact_data.loc[contact_data[contact_data.NickName==name1].index.values,'NickName']=input('\nEnter new NickName: ').title()
                print('\nsuccessfully Done','\n',contact_data,'\nPress 1 to Retry \nPress 2 to go back to Menu ')
                winsound.PlaySound('FILENAMEHERE.wav', winsound.SND_FILENAME)
                
                contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
            else:
                print("NickName Doesn't Exist \nPress 1 to Retry \nPress 2 to go back to Menu ")
                input12 = int(input("\nEnter Option Number: "))
                if input12 == 1:    continue
                elif input12 == 2:  return
        elif num1=='5':
            return
        
        else:
            print('Invalid Input \nPress 1 to Retry \nPress 2 to go back to Menu ')
            input12 = int(input("\nEnter Option Number: "))
            if input12 == 1:    continue          ## to return to same function 
            elif input12 == 2:  return            # to return to menu function

# %% [markdown]
# # Main code

# %%
def Contact_Book():
    flag = 4
    print('''
    .....Welcome to Contact Book Mangement....
    ...........To Open Press Y/N..............''')
    open1 = input('Y/N: ').title()
    if open1 == 'Y':
        while flag:
            print('''
            To Open Contact Book                 Press 1
            To Add New Contact                   Press 2
            To Search Contact                    Press 3
            To Update Name/Number/Email/NickName Press 4
            To Delete Contact                    Press 5
            To Exit                              Press 0 ''')
            Option1 = (input("Enter Option Number: "))
            if Option1 == '1':       print(contact_data)
                
            elif Option1 == '2':     add_details()

            elif Option1 == '3':     search_data()

            elif Option1 == '4':     update_data()

            elif Option1 == '5':     delete_data()

            elif Option1== '0':
                print('/nThank You For Visiting \n....Contact Book.....')
                break
            else:
                print('\n.....Invalid input.....','\n',f'You have {flag - 1} Chances Left.')
                flag-=1      

    elif open1 == 'N':     print('/nThank You For Visiting \n....Contact Book.....')
    else:                  print('Invalid Input')

# %%
Contact_Book()
contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
# Out:
#     .....Welcome to Contact Book Mangement....
#     ...........To Open Press Y/N..............
# Y/N: y
#
#             To Open Contact Book                 Press 1
#             To Add New Contact                   Press 2
#             To Search Contact                    Press 3
#             To Update Name/Number/Email/NickName Press 4
#             To Delete Contact                    Press 5
#             To Exit                              Press 0
# Enter Option Number: 1
#      Name      Number  Number1  Number2                     Email NickName
# 0      Ak           1      2.0      3.0                   abc@123     Akku
# 1  Akshat  8319082508      NaN      NaN  kunwarakshat18@gmail.com     Akki
#
#             To Open Contact Book                 Press 1
#             To Add New Contact                   Press 2
#             To Search Contact                    Press 3
#             To Update Name/Number/Email/NickName Press 4
#             To Delete Contact                    Press 5
#             To Exit                              Press 0
# Enter Option Number: 2
# Add Details
# Name: ak
#
# Name already exist
# Press 1 to Update Contact
# Press 2 For Other Name
#    Name  Number  Number1  Number2    Email NickName
# 0   Ak       1      2.0      3.0  abc@123     Akku
#
# Option: 1
# Enter new Name: akki
# Enter new Number: 94
# Do You want to Update Your Number1 Y/N
# n
# Do You want to Update Your Number2 Y/N
# n
# Do You want to Update Your Email Y/N
# n
# Do You want to Update Your NickName Y/N
# n
#
# Done Successful
#       Name      Number  Number1  Number2                     Email NickName
# 0    Akki          94      2.0      3.0                   abc@123     Akku
# 1  Akshat  8319082508      NaN      NaN  kunwarakshat18@gmail.com     Akki
#
#             To Open Contact Book                 Press 1
#             To Add New Contact                   Press 2
#             To Search Contact                    Press 3
#             To Update Name/Number/Email/NickName Press 4
#             To Delete Contact                    Press 5
#             To Exit                              Press 0

# %%
input12 = (input("\nEnter Option Number: "))
if input12 == '1':    print('continue')          ## to return to same function 
elif input12 == '2':  print('return') 
else: print('w')
